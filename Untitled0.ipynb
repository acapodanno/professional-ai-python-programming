# %% [markdown]
# <a href="https://colab.research.google.com/github/acapodanno/professional-ai-python-programming/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Il mio Primo notebook

# %%
print("Hello Colab")
# Out:
# Hello Colab

# %%
print("Hello again Colab")
# Out:
# Hello again Colab

# %% [markdown]
# # 3. Eseguire codice *Python*

# %%
a = 1
b = 2

# %%
c = a + b

# %%
c
# Out:
# 3

# %%
print("Ciao","\nAlessandro come stai?")
# Out:
# Ciao
# Alessandro come stai?

# %% [markdown]
# # 4. Grafici e visualizzazione

# %%
import matplotlib.pyplot as plt
a = [1,2,3,5,10,15,30,50,100]
plt.plot(a)

# %% [markdown]
# **testo in grassetto**# 4. Storage

# %% [markdown]
# # 4. Storage

# %%
from IPython.display import display, Image
display(Image("test.png"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
open("test.txt").read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3418100663.py in <cell line: 0>()
# ----> 1 open("test.txt").read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
from google.colab import files
_ = files.upload()

# %%
files.download("test.png")

# %% [markdown]
# # 6. Magic Command

# %%
a = 100
b = 1000
# %time a**b

# %%
# %%time

def fibonacci(n):
  if n==0:
    return 0
  elif n==1:
    return 1
  return fibonacci(n-1)+fibonacci(n-2)

fibonacci(30)

# %%
# %ls

# %%
# %pwd

# %%
# %mkdir folder

# %%
# %ls

# %%
# %cd folder

# %%
# %pwd
