# %% [markdown]
# <a href="https://colab.research.google.com/github/acapodanno/professional-ai-python-programming/blob/main/calcolatrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Calcolatrice:
  def __init__(self, numero1, numero2):
    self._numero1 = numero1
    self._numero2 = numero2

  def result(self,op):
    assert(op in ('+','-','*','/')), "Non esiste nessuna operazione disponibile"
    switcher = {
      '+': self._numero1 + self._numero2,
      '-': self._numero1 - self._numero2,
      '*': self._numero1 * self._numero,
      '-': self._numero1 / self._numero2
    }
    return switcher.get(op)
